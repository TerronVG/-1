# %% [markdown]
# <a href="https://colab.research.google.com/github/TerronVG/-1/blob/main/%D0%BC%D0%B0%D1%82%D1%80%D0%B8%D1%86%D1%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задание1

# %%
a=int(input())
s=[]
c=[]
z=0
for i in range(a):
  for n in range(a):
      z+=1
      c.append(z)
  s.append(c)
  c=[]
  print(s)
# Out:
# 2
# [[1, 2]]
# [[1, 2], [3, 4]]
